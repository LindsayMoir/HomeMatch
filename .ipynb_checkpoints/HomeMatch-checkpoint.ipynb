# %% [markdown]
# # HomeMatch
# Core Components of "HomeMatch"
#
# Understanding Buyer Preferences:
# - Buyers will input their requirements and preferences, such as location, property type, budget, amenities, and lifestyle choices.
# - The application uses LLMs to interpret these inputs in natural language, understanding nuanced requests beyond basic filters.
#
# Integrating with a Vector Database:
# - Connect "HomeMatch" with a vector database, where all available property listings are stored.
# - Utilize vector embeddings to match properties with buyer preferences, focusing on aspects like neighborhood vibes, architectural styles, and proximity to specific amenities.
# - Personalized Listing Description Generation:
#
# Matching
# - For each matched listing, use an LLM to rewrite the description in a way that highlights aspects most relevant to the buyer’s preferences.
# - Ensure personalization emphasizes characteristics appealing to the buyer without altering factual information about the property.
#
# Listing Presentation:
# - Output the personalized listing(s) as a text description of the listing.

# %% [markdown]
# ## Step 1: Setting Up the Python Application
# Import Libraries

# %%
# import libraries
import json
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.vectorstores import Chroma
import numpy as np
import os
import pandas as pd
import random
import re
from typing import Any, Dict, Optional, Tuple

# %%
# Create a Conda Environment YAML File
# !conda env export > environment.yml

# %%
# Generate requirements.txt file using pip freeze
# !pip freeze > requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lindsay\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %% [markdown]
# ### Global Variables

# %%
num = 15
location = 'Los Angeles, California, USA'

# %%
personalities = ['single, arrogant, rich, and female', 
                 'male, married, 2 kids, and middle class', 
                 'divorced middle aged woman, working 2 jobs, with dependent adult children', 
                 'young, nice, poor, male', 
                 'upper middle class married woman, husband works overseas, with no children']
personalities
# Out:
# ['single, arrogant, rich, and female',
#  'male, married, 2 kids, and middle class',
#  'divorced middle aged woman, working 2 jobs, with dependent adult children',
#  'young, nice, poor, male',
#  'upper middle class married woman, husband works overseas, with no children']

# %%
questions = ['Which houses are in Venice?',
             'What is the cheapest house that is available in your listings?',
             'Only provide me listings if the house has a pool']
questions
# Out:
# ['Which houses are in Venice?',
#  'What is the cheapest house that is available in your listings?',
#  'Only provide me listings if the house has a pool']

# %% [markdown]
# ### Common Functions

# %% [markdown]
# Due to the stochastic nature of LLMs there are a lot of situatons whereby the JSON returned had errrors in it and did not work. As a result, I used ChatGPT and CoPilot to build regex' to deal with the situations. I still had to put try and except blocks in on the json.loads() code. It is just VERY difficult to anticipate every error condition that will potentially happen and build clean up code that will deal with all instances.

# %%
def cleanup(response):
    
    # Fix spacing issues after commas and periods
    cleaned_response = re.sub(r'(?<=,)(\w)', r' \1', response)
    cleaned_response = re.sub(r'(?<=\.)(\w)', r' \1', cleaned_response)
    
    # Correct sequences of triple quotes
    cleaned_response = cleaned_response.replace('"   "', '", "')
    
    # We have a problem with contractions and possesives.
    # Replace single quotes with backticks (`) using regex
    pattern = r"\b\w+'\w*\b|\b'\w*\b"
    
    # Function to replace matched apostrophes with backticks
    def replace_apostrophe(match):
        return match.group().replace("'", "`")

    # Apply the regex pattern using sub with the replacement function
    cleaned_response = re.sub(pattern, replace_apostrophe, response)
    
    # Replace single quotes with double quotes for keys and values
    cleaned_response = cleaned_response.replace("'", '"')
    
    # Regex pattern to insert spaces after commas and periods
    pattern = r'([,.])(?=[^\s])'

    # Function to insert space after matched commas and periods
    def insert_space(match):
        return match.group(1) + ' '

    # Apply the regex pattern using sub with a function
    cleaned_response = re.sub(pattern, insert_space, cleaned_response)
    
    # Remove non-numeric characters except comma and then remove the commas
    cleaned_string = re.sub(r'[^\d,]', '', cleaned_response).replace(',', '')
    
    # Remove leading/trailing whitespace and newlines
    cleaned_response = cleaned_response.strip()
    
    # Remove newline characters from the JSON string
    cleaned_response = cleaned_response.replace('\n', ' ')
    
    return cleaned_response

# %%
def concat_row(row):
    
    preferences = (str(row.Q0) if row.Q0 is not None else '') + ' \n' + \
                  (str(row.Q1) if row.Q1 is not None else '') + ' \n' + \
                  (str(row.Q2) if row.Q2 is not None else '') + ' \n' + \
                  (str(row.Q3) if row.Q3 is not None else '') + ' \n' + \
                  (str(row.Q4) if row.Q4 is not None else '') + ' \n' + \
                  (str(row.Q5) if row.Q5 is not None else '') + ' \n' + \
                  (str(row.Q6) if row.Q6 is not None else '')
    
    return preferences

# %%
def create_df(input_list, output_file_name):
    
    temp_list = []
    
    # Load the data as a list of dictionaries
    for element in input_list:
        try:
            temp = json.loads(element)
            temp_list.append(temp)
        except Exception as e:
            print(f"Error occurred: {str(e)}")
            print('Non fatal error. We just get one fewer "preference" or "judgement".')
    
    if len(temp_list) == 5:
        index_values = personalities
    else:
        index_values = range(len(temp_list))

    # Create a DataFrame from the list of dictionaries
    output_df = pd.DataFrame(temp_list, index = index_values)

    # Write it to disk
    output_df.to_csv(output_file_name)

    # Display the DataFrame
    display(output_df)
    
    return output_df

# %% [markdown]
# ## Step 2: Generating Real Estate Listings

# %% [markdown]
# ### Create Prompt for Listings

# %%
listings_prompt = """
You are an experienced real estate professional in {location} with a flair for marketing. You have been asked to produce 
{num} new listings. Each listing is unique. Each listing has this information.

###
Neighborhoold_Name - Generate {num} names of well known districts for {location}.
Neighborhood_Description - Generate an 50 - 80 word description for each Neighborhood_Description. Use the 
Neighborhoold_Name for each listing as context for the description of the Neighborhood_Description
House_Description - For each House_Description generate an 50 - 80 word description of the House that is for sale.
Each house is unique. They vary in quality from low, medium, to high regardless of Neighborhoold_Name.
Square_Meters - Generate a RANDOM number from 100 to 500.
Bathrooms - Using the Square_Meters number for each listing, generate the number of bathrooms that the house will have
based on this formula. For every 100 square meters, the house should have at least 1 bathroom. This can vary slightly.
Bedrooms - Each house will have a minimum of 2 bedrooms. For every 100 Square_Meters > 200 Square_Meters, add 1 bedroom. 
This can vary slightly.
Price - The price will be based on this formula. 
1. Choose a number randomly between 500 and 2000. Call this random_number.
2. Multiply random_number by Square_Meters for each listing. This gives you the Price.

"""
print(listings_prompt)
# Out:
# You are an experienced real estate professional in {location} with a flair for marketing. You have been asked to produce
# {num} new listings. Each listing is unique. Each listing has this information.
#
# ###
# Neighborhoold_Name - Generate {num} names of well known districts for {location}.
# Neighborhood_Description - Generate an 50 - 80 word description for each Neighborhood_Description. Use the
# Neighborhoold_Name for each listing as context for the description of the Neighborhood_Description
# House_Description - For each House_Description generate an 50 - 80 word description of the House that is for sale.
# Each house is unique. They vary in quality from low, medium, to high regardless of Neighborhoold_Name.
# Square_Meters - Generate a RANDOM number from 100 to 500.
# Bathrooms - Using the Square_Meters number for each listing, generate the number of bathrooms that the house will have
# based on this formula. For every 100 square meters, the house should have at least 1 bathroom. This can vary slightly.
# Bedrooms - Each house will have a minimum of 2 bedrooms. For every 100 Square_Meters > 200 Square_Meters, add 1 bedroom.
# This can vary slightly.
# Price - The price will be based on this formula.
# 1. Choose a number randomly between 500 and 2000. Call this random_number.
# 2. Multiply random_number by Square_Meters for each listing. This gives you the Price.

# %%
json_spec = """
###
Return the output in JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it. 

[{'Neighborhoold_Name': 'Neighborhoold_Name',
 'Neighborhood_Description': 'Neighborhood_Description',
 'House_Description': 'House_Description',
 'Square_Meters': Square_Meters,
 'Bathrooms': Bathrooms,
 'Bedrooms': Bedrooms,
 'Price': Price},
{'Neighborhoold_Name': 'Neighborhoold_Name',
 'Neighborhood_Description': 'Neighborhood_Description',
 'House_Description': 'House_Description',
 'Square_Meters': Square_Meters,
 'Bathrooms': Bathrooms,
 'Bedrooms': Bedrooms,
 'Price': Price},
{'Neighborhoold_Name': 'Neighborhoold_Name',
 'Neighborhood_Description': 'Neighborhood_Description',
 'House_Description': 'House_Description',
 'Square_Meters': Square_Meters,
 'Bathrooms': Bathrooms,
 'Bedrooms': Bedrooms,
 'Price': Price},
 ...}]
###
"""
print(json_spec)
# Out:
# ###
# Return the output in JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it.
#
# [{'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description',
#  'House_Description': 'House_Description',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price},
# {'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description',
#  'House_Description': 'House_Description',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price},
# {'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description',
#  'House_Description': 'House_Description',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price},
#  ...}]
# ###

# %%
listings_prompt_formatted = listings_prompt.format(
    num = num,
    location = location
)
listings_prompt_formatted = listings_prompt_formatted + json_spec
print(listings_prompt_formatted)
# Out:
# You are an experienced real estate professional in Los Angeles, California, USA with a flair for marketing. You have been asked to produce
# 15 new listings. Each listing is unique. Each listing has this information.
#
# ###
# Neighborhoold_Name - Generate 15 names of well known districts for Los Angeles, California, USA.
# Neighborhood_Description - Generate an 50 - 80 word description for each Neighborhood_Description. Use the
# Neighborhoold_Name for each listing as context for the description of the Neighborhood_Description
# House_Description - For each House_Description generate an 50 - 80 word description of the House that is for sale.
# Each house is unique. They vary in quality from low, medium, to high regardless of Neighborhoold_Name.
# Square_Meters - Generate a RANDOM number from 100 to 500.
# Bathrooms - Using the Square_Meters number for each listing, generate the number of bathrooms that the house will have
# based on this formula. For every 100 square meters, the house should have at least 1 bathroom. This can vary slightly.
# Bedrooms - Each house will have a minimum of 2 bedrooms. For every 100 Square_Meters > 200 Square_Meters, add 1 bedroom.
# This can vary slightly.
# Price - The price will be based on this formula.
# 1. Choose a number randomly between 500 and 2000. Call this random_number.
# 2. Multiply random_number by Square_Meters for each listing. This gives you the Price.
#
#
# ###
# Return the output in JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it.
#
# [{'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description',
#  'House_Description': 'House_Description',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price},
# {'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description',
#  'House_Description': 'House_Description',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price},
# {'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description',
#  'House_Description': 'House_Description',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price},
#  ...}]
# ###

# %% [markdown]
# ### Completion Model
# Instantiate the model and run it with the prompt.

# %%
# Get key
open_ai_key = pd.read_csv('D:\OneDrive\Security\keys.csv')
open_ai_key = open_ai_key[open_ai_key['Organization'] == 'Open_AI']['Key'].iloc[0]

# Set the environment variable
os.environ["OPENAI_API_KEY"] = open_ai_key

# Create the model
descriptions_model = OpenAI(model = 'gpt-3.5-turbo-instruct', 
                            temperature = .3,
                            max_tokens = 3500)

# %%
# Call the model with the formatted prompt. 
response = descriptions_model.predict(listings_prompt_formatted)

# Clean it up and prepare it for a dataframe or viewing as a list
cleaned_response = cleanup(response)

# %%
# Load the data as a list of dictionaries
dict_list = json.loads(cleaned_response)

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(dict_list)

# Write the dataframe to disk
df.to_csv('listings.csv')

# Display the DataFrame
df
# Out:
#    Neighborhoold_Name                           Neighborhood_Description  \
# 0           Hollywood  Hollywood is known as the entertainment capita...
# 1       Beverly Hills  Beverly Hills is known for its luxurious lifes...
# 2        Venice Beach  Venice Beach is a vibrant and eclectic neighbo...
# 3             Bel Air  Bel Air is a prestigious and exclusive neighbo...
# 4         Silver Lake  Silver Lake is a hip and trendy neighborhood k...
# 5        Santa Monica  Santa Monica is a beachfront neighborhood know...
# 6            Westwood  Westwood is a bustling neighborhood known for ...
# 7            Downtown  Downtown is the heart of Los Angeles, known fo...
# 8           Echo Park  Echo Park is a trendy and up-and-coming neighb...
# 9      Marina Del Rey  Marina Del Rey is a waterfront neighborhood kn...
# 10           Pasadena  Pasadena is a charming and historic neighborho...
# 11     West Hollywood  West Hollywood is a trendy and vibrant neighbo...
# 12             Malibu  Malibu is a beachfront neighborhood known for ...
# 13        Culver City  Culver City is a bustling neighborhood known f...
# 14          Brentwood  Brentwood is an upscale and exclusive neighbor...
#
#                                     House_Description  Square_Meters  \
# 0   This beautiful home in Hollywood offers the pe...            300
# 1   Live like a celebrity in this stunning Beverly...            400
# 2   Experience the laid-back lifestyle of Venice B...            200
# 3   Live like royalty in this magnificent Bel Air ...            500
# 4   This modern and stylish home in Silver Lake is...            300
# 5   Live just steps away from the beach in this ch...            200
# 6   This spacious home in Westwood is perfect for ...            400
# 7   Live in the heart of the city in this stunning...            200
# 8   This charming home in Echo Park offers the per...            300
# 9   Live the beach life in this stunning Marina De...            400
# 10  This beautiful home in Pasadena offers the per...            200
# 11  Live in the heart of West Hollywood in this st...            300
# 12  Live the beach life in this magnificent Malibu...            500
# 13  This modern and stylish home in Culver City is...            200
# 14  Live like a celebrity in this stunning Brentwo...            400
#
#     Bathrooms  Bedrooms    Price
# 0           3         3  1500000
# 1           4         4  2000000
# 2           2         2  1000000
# 3           5         5  2500000
# 4           3         3  1500000
# 5           2         2  1000000
# 6           4         4  2000000
# 7           2         2  1000000
# 8           3         3  1500000
# 9           4         4  2000000
# 10          2         2  1000000
# 11          3         3  1500000
# 12          5         5  2500000
# 13          2         2  1000000
# 14          4         4  2000000

# %% [markdown]
# ## Step 3: Storing Listings in a Vector Database

# %%
# Convert DataFrame to a list of dictionaries
dict_list = df.to_dict(orient="records")

# Convert each dictionary to a string
dict_list_string = [str(d) for d in dict_list]

dict_list_string[0]
# Out:
# "{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"

# %%
# Initialize your embedding function (e.g., OpenAIEmbeddings)
embeddings = OpenAIEmbeddings()

# Create the vector store
chromadb = Chroma.from_texts(dict_list_string, embedding=embeddings)

# Persist the vector store to a directory
chromadb.persist()

# %% [markdown]
# ### Query the Vector Database

# %%
# Query chromadb
question = 'Which houses are in Venice'

# Get the most similar documents
results = chromadb.similarity_search(question)

print(len(results))
results[0]
# Out:
# 4
# Document(page_content="{'Neighborhoold_Name': 'Venice', 'Neighborhood_Description': 'Venice is a vibrant and eclectic neighborhood in Los Angeles, known for its bohemian vibe and beautiful beach. It is a popular spot for artists and creatives, with colorful murals and street performers lining the famous Venice Boardwalk. The neighborhood also offers a variety of trendy restaurants, boutique shops, and a lively nightlife. ', 'House_Description': 'This charming house in Venice is the perfect beach retreat. With a spacious rooftop deck, you can enjoy stunning ocean views and beautiful sunsets. The house features an open floor plan with plenty of natural light and a cozy fireplace. The backyard is a private oasis with a hot tub and outdoor shower. Don`t miss your chance to live in this unique and vibrant neighborhood. ', 'Square_Meters': 200, 'Bathrooms': 2, 'Bedrooms': 3, 'Price': 1000000}")

# %% [markdown]
# ## Step 4: Building the User Preference Interface
#
# I am going to pose these questions to OpenAI and see what the LLMs responses are. I will do it for 5 different people and collect the answers to each one of the questions to build up a user profile for each "person"

# %%
questions = [   
"Q0: How big do you want your house to be? ",
"Q1: What are the 3 most important things for you in choosing this property? ", 
"Q2: Which amenities would you like? ", 
"Q3: Which transportation options are important to you? ",
"Q4: Who will be living in the home: their names, ages, sex, and relationship to you? ",
"Q5: How urban do you want your neighborhood to be? ",   
"Q6: Is there anything else that you think I shoud know? "
]
questions
# Out:
# ['Q0: How big do you want your house to be? ',
#  'Q1: What are the 3 most important things for you in choosing this property? ',
#  'Q2: Which amenities would you like? ',
#  'Q3: Which transportation options are important to you? ',
#  'Q4: Who will be living in the home: their names, ages, sex, and relationship to you? ',
#  'Q5: How urban do you want your neighborhood to be? ',
#  'Q6: Is there anything else that you think I shoud know? ']

# %%
prompt_for_asking_questions = """
You are a(n) {personality} looking for a house in {location}. Please pay attention to the type of buyer you are.
I am a professional real estate agent helping you purchase a home. Answer each of these questions. 
{questions}
With this information I will help you find the perfect home for you. Please limit your answers to 100 words.
"""
print(prompt_for_asking_questions)
# Out:
# You are a(n) {personality} looking for a house in {location}. Please pay attention to the type of buyer you are.
# I am a professional real estate agent helping you purchase a home. Answer each of these questions.
# {questions}
# With this information I will help you find the perfect home for you. Please limit your answers to 100 words.

# %%
json_spec = """
###
Return the answers in this JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it. 
All commas('), square brackets([], colons(:), and ellipsis({}) must be exactly as you see here. Check your work. 
This is important. 


{'Q0': 'Answer to Q0',
 'Q1': 'Answer to Q1',
 'Q2': 'Answer to Q2',
 'Q3': 'Answer to Q3',
 'Q4': 'Answer to Q4',
 'Q5': 'Answer to Q5',
 'Q6': 'Answer to Q6'}
###
"""
print(json_spec)
# Out:
# ###
# Return the answers in this JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it.
# All commas('), square brackets([], colons(:), and ellipsis({}) must be exactly as you see here. Check your work.
# This is important.
#
#
# {'Q0': 'Answer to Q0',
#  'Q1': 'Answer to Q1',
#  'Q2': 'Answer to Q2',
#  'Q3': 'Answer to Q3',
#  'Q4': 'Answer to Q4',
#  'Q5': 'Answer to Q5',
#  'Q6': 'Answer to Q6'}
# ###

# %%
# Change the modeltemperature to make it more creative.
answers_model = OpenAI(model = 'gpt-3.5-turbo-instruct', 
                            temperature = .8,
                            max_tokens = 3300)

# %%
personal_answers = []
for personality in personalities:
    formatted_prompt = prompt_for_asking_questions.format(
        personality = personality,
        location = location,
        questions = questions)
    
    # Combine the prompts
    formatted_prompt = formatted_prompt + json_spec
    
    # Call the model with the formatted prompt. 
    response = answers_model.predict(formatted_prompt)
    
    cleaned_response = cleanup(response)
    
    # Append to personal_answers
    personal_answers.append(cleaned_response)
    
personal_answers[0]
# Out:
# '{"Q0": "I would like my house to be at least 3, 000 square feet. ",  "Q1": "The most important things for me in choosing this property are location, security, and luxury. ",  "Q2": "I would like amenities such as a pool, gym, and home theater. ",  "Q3": "Having easy access to public transportation and being close to major highways is important to me. ",  "Q4": "I will be living in the home alone. ",  "Q5": "I would like a neighborhood that is urban but still has some peace and quiet. ",  "Q6": "I would like the house to have a modern design and be located in a prestigious neighborhood. "}'

# %%
# Create df
personal_df = create_df(personal_answers, 'personal_df.csv')
# Out:
#                                                                                                    Q0  \
# single, arrogant, rich, and female                  I would like my house to be at least 3, 000 sq...
# male, married, 2 kids, and middle class             I am looking for a house that is around 2, 000...
# divorced middle aged woman, working 2 jobs, wit...  I would like my house to be at least 1500 squa...
# young, nice, poor, male                             I am looking for a house that is around 1000-1...
# upper middle class married woman, husband works...  Answer to Q0: I am looking for a house that is...
#
#                                                                                                    Q1  \
# single, arrogant, rich, and female                  The most important things for me in choosing t...
# male, married, 2 kids, and middle class             The most important things for me in choosing t...
# divorced middle aged woman, working 2 jobs, wit...  The 3 most important things for me in choosing...
# young, nice, poor, male                             The 3 most important things for me in choosing...
# upper middle class married woman, husband works...  Answer to Q1: The 3 most important things for ...
#
#                                                                                                    Q2  \
# single, arrogant, rich, and female                  I would like amenities such as a pool, gym, an...
# male, married, 2 kids, and middle class             I would like amenities such as a backyard, a g...
# divorced middle aged woman, working 2 jobs, wit...  I would like amenities such as a backyard, gar...
# young, nice, poor, male                             I would like amenities such as a washer/dryer,...
# upper middle class married woman, husband works...  Answer to Q2: I would like a house with a back...
#
#                                                                                                    Q3  \
# single, arrogant, rich, and female                  Having easy access to public transportation an...
# male, married, 2 kids, and middle class             Having access to public transportation and maj...
# divorced middle aged woman, working 2 jobs, wit...  Proximity to public transportation and easy ac...
# young, nice, poor, male                             I would prefer a neighborhood with reliable pu...
# upper middle class married woman, husband works...  Answer to Q3: The most important transportatio...
#
#                                                                                                    Q4  \
# single, arrogant, rich, and female                               I will be living in the home alone.
# male, married, 2 kids, and middle class             My wife and I, both in our 30s, and our 2 youn...
# divorced middle aged woman, working 2 jobs, wit...  My dependent adult children, ages 20 and 23, w...
# young, nice, poor, male                             I will be living in the home with my partner, ...
# upper middle class married woman, husband works...  Answer to Q4: My husband and I will be living ...
#
#                                                                                                    Q5  \
# single, arrogant, rich, and female                  I would like a neighborhood that is urban but ...
# male, married, 2 kids, and middle class             I prefer a suburban neighborhood with a good s...
# divorced middle aged woman, working 2 jobs, wit...  I would like a moderately urban neighborhood, ...
# young, nice, poor, male                             I would like a neighborhood that is urban, but...
# upper middle class married woman, husband works...  Answer to Q5: I prefer a neighborhood that is ...
#
#                                                                                                    Q6
# single, arrogant, rich, and female                  I would like the house to have a modern design...
# male, married, 2 kids, and middle class             I would like to live in a family-friendly comm...
# divorced middle aged woman, working 2 jobs, wit...  I would prefer a newer or recently renovated h...
# young, nice, poor, male                             As a young professional on a tight budget, I a...
# upper middle class married woman, husband works...  Answer to Q6: I would also like to have a gara...

# %% [markdown]
# ### Buyer Preference Parsing:
# - Implement logic to interpret and structure these preferences for querying the vector database.
# - Ask the first question (Q0) of each of the buyers.

# %%
for row in personal_df.itertuples():
    print(row.Q0)
    results = chromadb.similarity_search(row.Q0)[0]
    print(row.Index, '\n', results, '\n###\n')
# Out:
# I would like my house to be at least 3, 000 square feet.
# single, arrogant, rich, and female
#  page_content="{'Neighborhoold_Name': 'Beverly Hills', 'Neighborhood_Description': 'Beverly Hills is a luxurious neighborhood known for its extravagant mansions, high-end shopping, and celebrity sightings. It is located in the heart of Los Angeles and offers stunning views of the city. Residents enjoy the finest dining and entertainment options, as well as top-rated schools and a safe community. ', 'House_Description': 'This stunning mansion in Beverly Hills boasts 400 square meters of living space and features high-end finishes and luxurious amenities. With 4 bedrooms and 4 bathrooms, this house is perfect for a family looking for a spacious and elegant home. Enjoy the beautiful California weather in the private backyard with a pool and outdoor kitchen. Don`t miss the opportunity to live in the prestigious neighborhood of Beverly Hills. ', 'Square_Meters': 400, 'Bathrooms': 4, 'Bedrooms': 4, 'Price': 2000000}"
# ###
#
# I am looking for a house that is around 2, 000 to 2, 500 square feet.
# male, married, 2 kids, and middle class
#  page_content="{'Neighborhoold_Name': 'Pasadena', 'Neighborhood_Description': 'Pasadena is a charming and historic neighborhood known for its beautiful architecture and tree-lined streets. It is located just outside of Los Angeles and offers a peaceful and family-friendly atmosphere. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This elegant colonial-style home in Pasadena offers 400 square meters of living space and features classic and timeless design. With 4 bedrooms and 4 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the opportunity to live in this desirable and prestigious neighborhood. ', 'Square_Meters': 400, 'Bathrooms': 4, 'Bedrooms': 4, 'Price': 2000000}"
# ###
#
# I would like my house to be at least 1500 square feet.
# divorced middle aged woman, working 2 jobs, with dependent adult children
#  page_content="{'Neighborhoold_Name': 'Pasadena', 'Neighborhood_Description': 'Pasadena is a charming and historic neighborhood known for its beautiful architecture and tree-lined streets. It is located just outside of Los Angeles and offers a peaceful and family-friendly atmosphere. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This elegant colonial-style home in Pasadena offers 400 square meters of living space and features classic and timeless design. With 4 bedrooms and 4 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the opportunity to live in this desirable and prestigious neighborhood. ', 'Square_Meters': 400, 'Bathrooms': 4, 'Bedrooms': 4, 'Price': 2000000}"
# ###
#
# I am looking for a house that is around 1000-1500 square feet.
# young, nice, poor, male
#  page_content="{'Neighborhoold_Name': 'Pasadena', 'Neighborhood_Description': 'Pasadena is a charming and historic neighborhood known for its beautiful architecture and tree-lined streets. It is located just outside of Los Angeles and offers a peaceful and family-friendly atmosphere. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This elegant colonial-style home in Pasadena offers 400 square meters of living space and features classic and timeless design. With 4 bedrooms and 4 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the opportunity to live in this desirable and prestigious neighborhood. ', 'Square_Meters': 400, 'Bathrooms': 4, 'Bedrooms': 4, 'Price': 2000000}"
# ###
#
# Answer to Q0: I am looking for a house that is around 2, 000 to 3, 000 square feet.
# upper middle class married woman, husband works overseas, with no children
#  page_content="{'Neighborhoold_Name': 'Pasadena', 'Neighborhood_Description': 'Pasadena is a charming and historic neighborhood known for its beautiful architecture and tree-lined streets. It is located just outside of Los Angeles and offers a peaceful and family-friendly atmosphere. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This elegant colonial-style home in Pasadena offers 400 square meters of living space and features classic and timeless design. With 4 bedrooms and 4 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the opportunity to live in this desirable and prestigious neighborhood. ', 'Square_Meters': 400, 'Bathrooms': 4, 'Bedrooms': 4, 'Price': 2000000}"
# ###

# %% [markdown]
# The code works, but ... you can see that some of the answers while they may be the best in the database are certainly off the mark.

# %% [markdown]
# ## Step 5: Searching Based on Preferences
#
# - Semantic Search Implementation: Use the structured buyer preferences to perform a semantic search on the vector database, retrieving listings that most closely match the user's requirements.
# - Listing Retrieval Logic: Fine-tune the retrieval algorithm to ensure that the most relevant listings are selected based on the semantic closeness to the buyer’s preferences.
#
# - I will loop thru each buyers answers to each question and provide that answer to chromadb and see what the search results are. I will put those answers in a df called answers_df. Since there are only 15 entries, I will limit the answers to just the top 1. The answers_df, will be structured the same as the personaL_df.

# %%
# Results list for entire dataframe
df_results_list = []

# Exterior loop to use answers to search chromadb
for row in personal_df.itertuples():
    
    # Create the empty list
    row_results_list = []
    
    # Interior loop to acroww each row
    for preference in row:
        
        # Do the search
        results = chromadb.similarity_search(preference)[0]
        
        # So that it is obvious, include the preference that was submitted to chromadb
        # Make this a tuple
        pair = preference, results
        
        # Append search results in the row results list
        row_results_list.append(pair)
        
    # Append each row_results_list to the entire ef_results_list
    df_results_list.append(row_results_list)

# %% [markdown]
# ### Judging Quality of Results
#
# There are some specific preferences being stated and the system is returning a lot of text. Difficult to say if this is working unless you painstakingly went thru each preference, results pair and made a call on that.
#
# However, this is something that LLMs typically do quite well. So, lets provide 3 pieces of information to the LLM. They are the profile of the buyer, the preference, and the results. Then ask the LLM based on what the result was, is the preference stated satisfied by that result? This will require some prompt engineering and then simply a score of 0 or 1 that means NO or YES.
#
# There are 35 preferences being posed here. Lets see how it does. Since there is a lot of text going back and forth here, what I will do is put this in a loop that calls the LLM for each buyer and ONLY gives them 1 buyer_profile, preference, result tuple to work on. This will take awhile to do this. Generally speaking OpenAI does not like this many calls in.

# %%
buyer_prompt = """
You are a(n) {personality} BUYER. You have stated this PREFERENCE:
###
{preference} 
###
to your real estate agent here in {location}. 
Please answer if this LISTING:
###
{listing} 
###
satisfies your Preference.
###
If it DOES NOT stafisfy your Preference return a 0 as NUMBER or if it DOES satisfy your Preference return a 1 as NUMBER.
Next provide your REASON.
###
"""
print(buyer_prompt)
# Out:
# You are a(n) {personality} BUYER. You have stated this PREFERENCE:
# ###
# {preference}
# ###
# to your real estate agent here in {location}.
# Please answer if this LISTING:
# ###
# {listing}
# ###
# satisfies your Preference.
# ###
# If it DOES NOT stafisfy your Preference return a 0 as NUMBER or if it DOES satisfy your Preference return a 1 as NUMBER.
# Next provide your REASON.
# ###

# %%
json_spec = """
###
Return the output in JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it.

{'Buyer': "BUYER",
 'Preference': "PREFERENCE",
 'Number': NUMBER,
 'Reason': "REASON"}

###
"""
print(json_spec)
# Out:
# ###
# Return the output in JSON format as follows. Please adhere EXACTLY to this ouput. Do not deviate from it.
#
# {'Buyer': "BUYER",
#  'Preference': "PREFERENCE",
#  'Number': NUMBER,
#  'Reason': "REASON"}
#
# ###

# %%
judging_results = []
for idx, buyer in enumerate(df_results_list):
    
    # Outside loops gets the buyer froom the original personalities list
    personality_type = personalities[idx]
    print(personality_type)
    
    # Goes thru each buyer's preferences and asks them if the listing satisfies their itch
    for int_idx, temp in enumerate(buyer):
        
        # The first tuple is a throw away.
        if int_idx ==0:
            pass
        
        else:
            # Split the list into its component parts.
            preference, listing = temp
            
            # Format the prompt
            preference_prompt_formatted = buyer_prompt.format(
                personality = personality_type,
                preference = preference,
                location = location,
                listing = listing)

            judging_prompt = preference_prompt_formatted + json_spec

            # Call the model with the formatted prompt. 
            response = answers_model.predict(judging_prompt)

            # Clean up the string
            cleaned_response = cleanup(response)

            # Append to personal_answers
            judging_results.append(cleaned_response)

len(judging_results)
# Out:
# single, arrogant, rich, and female
# male, married, 2 kids, and middle class
# divorced middle aged woman, working 2 jobs, with dependent adult children
# young, nice, poor, male
# upper middle class married woman, husband works overseas, with no children
# 35

# %%
# Create the df
judging_df = create_df(judging_results, 'judging_df.csv')
# Out:
# Error occurred: Expecting ',' delimiter: line 1 column 652 (char 651)
# Non fatal error. We just get one fewer "preference" or "judgement".
# Error occurred: Expecting ',' delimiter: line 1 column 64 (char 63)
# Non fatal error. We just get one fewer "preference" or "judgement".
#                                                 Buyer  \
# 0                Single, arrogant, rich, female BUYER
# 1                Single, arrogant, rich, female BUYER
# 2                Single, arrogant, rich, female BUYER
# 3            single, arrogant, rich, and female BUYER
# 4                Single, Arrogant, Rich, Female Buyer
# 5                Single, arrogant, rich, female buyer
# 6                Single, arrogant, rich, female BUYER
# 7       male, married, 2 kids, and middle class BUYER
# 8                                                male
# 9                                                male
# 10                                               Male
# 11      male, married, 2 kids, and middle class BUYER
# 12                                               Male
# 13                                               male
# 14  divorced middle aged woman, working 2 jobs, wi...
# 15  Divorced middle aged woman working 2 jobs with...
# 16  Divorced middle aged woman, working 2 jobs, wi...
# 17  Divorced middle aged woman working 2 jobs with...
# 18          Divorced middle aged woman working 2 jobs
# 19                         Divorced Middle Aged Woman
# 20  divorced middle aged woman working 2 jobs with...
# 21                      Young, Nice, Poor, Male Buyer
# 22                      young, nice, poor, male BUYER
# 23                      young, nice, poor, male BUYER
# 24                      young, nice, poor, male BUYER
# 25                      young, nice, poor, male BUYER
# 26                                              BUYER
# 27                   upper middle class married woman
# 28  upper middle class married woman, husband work...
# 29                   upper middle class married woman
# 30  upper middle class married woman, husband work...
# 31                   Upper Middle Class Married Woman
# 32  upper middle class married woman with no children
#
#                                            Preference  Number  \
# 0      My house should be at least 3, 000 square feet       1
# 1                          Location, security, luxury       1
# 2     Amenities such as a pool, gym, and home theater       1
# 3   Having easy access to public transportation an...       1
# 4                                        Living alone       1
# 5   I would like a neighborhood that is urban but ...       1
# 6   I would like the house to have a modern design...       1
# 7   I am looking for a house that is around 2, 000...       0
# 8   The most important things for me in choosing t...       0
# 9   Amenities such as a backyard, a garage, and a ...       1
# 10  Having access to public transportation and maj...       1
# 11  My wife and I, both in our 30s, and our 2 youn...       1
# 12  I prefer a suburban neighborhood with a good s...       1
# 13  I would like to live in a family-friendly comm...       1
# 14  I would like my house to be at least 1500 squa...       0
# 15                            Location, Price, Safety       1
# 16         Backyard, garage parking, and laundry room       1
# 17  Proximity to public transportation and easy ac...       1
# 18  My dependent adult children, ages 20 and 23, w...       1
# 19  Moderately Urban Neighborhood with Convenient ...       1
# 20  Newer or recently renovated home in a quiet an...       1
# 21  I am looking for a house that is around 1000-1...       0
# 22  The 3 most important things for me in choosing...       1
# 23  Amenities: washer/dryer, updated kitchen, smal...       0
# 24  a neighborhood with reliable public transporta...       1
# 25  I would like a neighborhood that is urban, but...       1
# 26  As a young professional on a tight budget, I a...       0
# 27  a house that is around 2, 000 to 3, 000 square...       1
# 28         location, safety, convenience to amenities       1
# 29  I would like a house with a backyard, a modern...       1
# 30  proximity to public transportation and easy ac...       1
# 31                    Living in the home with husband       1
# 32  moderately urban neighborhood with a mix of re...       1
#
#                                                Reason
# 0   This listing has 400 square meters or approxim...
# 1   This listing in Beverly Hills, a luxurious and...
# 2   This listing satisfies all of the buyer"s stat...
# 3   The house is located in Downtown Los Angeles, ...
# 4   The house has 5 bedrooms and 5 bathrooms, prov...
# 5   This listing in Brentwood satisfies my prefere...
# 6   The house is located in Beverly Hills, which i...
# 7   The listed house has 400 square meters, which ...
# 8   This property is located in Pasadena, which is...
# 9   This listing offers a backyard, a garage, and ...
# 10  This listing is located in Downtown Los Angele...
# 11  This listing has 3 bedrooms and 2 bathrooms, w...
# 12  The neighborhood of Pasadena is known for its ...
# 13  This listing is in Pasadena, which is known fo...
# 14  The house in the listing only has 400 square m...
# 15  This listing satisfies all of the buyer`s stat...
# 16  This listing in Brentwood offers all the ameni...
# 17  This listing is located in the Downtown neighb...
# 18  This listing satisfies my preference as it off...
# 19  The listing is for a modern loft in Downtown L...
# 20  The listing is located in a charming and famil...
# 21  The house description states that the house is...
# 22  The listing is in the Hollywood neighborhood, ...
# 23  The listing does not mention any of the prefer...
# 24  Pasadena offers a variety of public transporta...
# 25  The neighborhood of Downtown, despite being ur...
# 26  The house is located in Pasadena which is outs...
# 27  The house has 400 square meters, which is equi...
# 28  This listing satisfies all of my preferences. ...
# 29  This listing in Brentwood meets all of my pref...
# 30  The Downtown neighborhood offers easy access t...
# 31  This listing offers 3 bedrooms and 2 bathrooms...
# 32  This listing is located in Downtown Los Angele...

# %%
accuracy_score = judging_df['Number'].sum() / judging_df.shape[0]
print('It has an accuracy score of:', round(accuracy_score, 2)*100, '%')
# Out:
# It has an accuracy score of: 82.0 %

# %% [markdown]
# However, when I look at what the "judge" is complaining about, I am not sure that I would not have said the listing was fine. A panel of "3 judges" is what is needed here. Get them to vote and we simply take the majority opinion each time. For a production application this would be a good idea. However, for this one, it is not necessary.

# %%
judging_results[:5]
# Out:
# ['{"Buyer": "Single, arrogant, rich, female BUYER",  "Preference": "My house should be at least 3, 000 square feet",  "Number": 1,  "Reason": "This listing has 400 square meters or approximately 4, 300 square feet, which satisfies my preference for a large living space. "}',
#  '{"Buyer": "Single, arrogant, rich, female BUYER",  "Preference": "Location, security, luxury",  "Number": 1,  "Reason": "This listing in Beverly Hills, a luxurious and safe neighborhood, offers high-end finishes and luxurious amenities, as well as stunning views of the city. With 4 bedrooms and 4 bathrooms, it provides plenty of space for a family. Additionally, the private backyard with a pool and outdoor kitchen allows for enjoying the beautiful California weather. Overall, this property satisfies all of the stated preferences of the buyer. "}',
#  '{"Buyer": "Single, arrogant, rich, female BUYER",  "Preference": "Amenities such as a pool, gym, and home theater",  "Number": 1,  "Reason": "This listing satisfies all of the buyer\\"s stated preferences. The house is located in the desirable neighborhood of Hollywood, known for its luxurious homes and trendy restaurants. The house itself has a spacious backyard perfect for entertaining guests and also has 3 bedrooms and 2 bathrooms, making it suitable for a growing family. Additionally, the listing price of $1, 500, 000 is within the buyer\\"s budget as a wealthy individual. "}',
#  '{"Buyer": "single, arrogant, rich, and female BUYER",  "Preference": "Having easy access to public transportation and being close to major highways is important to me. ",  "Number": 1,  "Reason": "The house is located in Downtown Los Angeles, which is known for its easy access to public transportation and its central location near major highways. Additionally, the house itself offers modern and sleek design, making it a desirable option for a single, successful buyer. The rooftop pool and fitness center also add to the appeal for a luxury lifestyle. "}',
#  '{"Buyer": "Single, Arrogant, Rich, Female Buyer",  "Preference": "Living alone",  "Number": 1,  "Reason": "The house has 5 bedrooms and 5 bathrooms, providing ample space for both relaxation and entertainment. It also offers privacy and luxury in the prestigious and exclusive neighborhood of Bel Air. "}']

# %% [markdown]
# ### Fine-tune the Retrieval Algorithm
# Lets see if this changes if we use euclidean distance as opposed to the default cosine distance. I don't want to do this on large number of queries. Lets just do it on some new questions that I have dreamed up here and see if the results change.

# %%
for question in questions:
    
    print('###\n', question)

    # Get the most similar documents using Euclidean distance
    results_euclidean = chromadb.similarity_search(question, k=3, distance_metric='euclidean')

    print(f"Results (Euclidean Distance): {len(results_euclidean)}")
    print(results_euclidean[0])

    # Get the most similar documents using Cosine distance
    results_cosine = chromadb.similarity_search(question, k=3, distance_metric='cosine')

    print(f"Results (Cosine Distance): {len(results_cosine)}")
    print(results_cosine[0])
    
    if results_euclidean == results_cosine:
        print('\nResults for both Euclidean and Cosine distance searches are identical\n')
    else:
        print('\nResults are different!\n')
# Out:
# ###
#  Q0: How big do you want your house to be?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical
#
# ###
#  Q1: What are the 3 most important things for you in choosing this property?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical
#
# ###
#  Q2: Which amenities would you like?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Marina del Rey', 'Neighborhood_Description': 'Marina del Rey is a waterfront neighborhood known for its beautiful marina and upscale lifestyle. It offers a mix of high-rise condos and single-family homes, as well as a variety of dining and shopping options. Residents also enjoy easy access to the beach and other popular destinations in Los Angeles. ', 'House_Description': 'This luxurious condo in Marina del Rey offers 300 square meters of living space and features stunning views of the marina and ocean. With 3 bedrooms and 3 bathrooms, this house is perfect for those who love to entertain. The building also offers a pool, fitness center, and other high-end amenities. Don`t miss the chance to live in this exclusive and sought-after neighborhood. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Marina del Rey', 'Neighborhood_Description': 'Marina del Rey is a waterfront neighborhood known for its beautiful marina and upscale lifestyle. It offers a mix of high-rise condos and single-family homes, as well as a variety of dining and shopping options. Residents also enjoy easy access to the beach and other popular destinations in Los Angeles. ', 'House_Description': 'This luxurious condo in Marina del Rey offers 300 square meters of living space and features stunning views of the marina and ocean. With 3 bedrooms and 3 bathrooms, this house is perfect for those who love to entertain. The building also offers a pool, fitness center, and other high-end amenities. Don`t miss the chance to live in this exclusive and sought-after neighborhood. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical
#
# ###
#  Q3: Which transportation options are important to you?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Venice Beach', 'Neighborhood_Description': 'Venice Beach is a unique and eclectic neighborhood known for its bohemian vibe and artistic community. It is located right on the beach and offers a laid-back lifestyle with plenty of outdoor activities, such as surfing and biking. Residents also enjoy a variety of trendy restaurants, boutique shops, and street performers. ', 'House_Description': 'This modern beach house in Venice Beach offers 300 square meters of living space and features sleek and stylish design. With 3 bedrooms and 3 bathrooms, this house is perfect for those who love to entertain. The rooftop deck offers stunning ocean views and is perfect for hosting summer parties. Don`t miss the opportunity to live in this vibrant and dynamic neighborhood. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Venice Beach', 'Neighborhood_Description': 'Venice Beach is a unique and eclectic neighborhood known for its bohemian vibe and artistic community. It is located right on the beach and offers a laid-back lifestyle with plenty of outdoor activities, such as surfing and biking. Residents also enjoy a variety of trendy restaurants, boutique shops, and street performers. ', 'House_Description': 'This modern beach house in Venice Beach offers 300 square meters of living space and features sleek and stylish design. With 3 bedrooms and 3 bathrooms, this house is perfect for those who love to entertain. The rooftop deck offers stunning ocean views and is perfect for hosting summer parties. Don`t miss the opportunity to live in this vibrant and dynamic neighborhood. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical
#
# ###
#  Q4: Who will be living in the home: their names, ages, sex, and relationship to you?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical
#
# ###
#  Q5: How urban do you want your neighborhood to be?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Venice Beach', 'Neighborhood_Description': 'Venice Beach is a unique and eclectic neighborhood known for its bohemian vibe and artistic community. It is located right on the beach and offers a laid-back lifestyle with plenty of outdoor activities, such as surfing and biking. Residents also enjoy a variety of trendy restaurants, boutique shops, and street performers. ', 'House_Description': 'This modern beach house in Venice Beach offers 300 square meters of living space and features sleek and stylish design. With 3 bedrooms and 3 bathrooms, this house is perfect for those who love to entertain. The rooftop deck offers stunning ocean views and is perfect for hosting summer parties. Don`t miss the opportunity to live in this vibrant and dynamic neighborhood. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Venice Beach', 'Neighborhood_Description': 'Venice Beach is a unique and eclectic neighborhood known for its bohemian vibe and artistic community. It is located right on the beach and offers a laid-back lifestyle with plenty of outdoor activities, such as surfing and biking. Residents also enjoy a variety of trendy restaurants, boutique shops, and street performers. ', 'House_Description': 'This modern beach house in Venice Beach offers 300 square meters of living space and features sleek and stylish design. With 3 bedrooms and 3 bathrooms, this house is perfect for those who love to entertain. The rooftop deck offers stunning ocean views and is perfect for hosting summer parties. Don`t miss the opportunity to live in this vibrant and dynamic neighborhood. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical
#
# ###
#  Q6: Is there anything else that you think I shoud know?
# Results (Euclidean Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
# Results (Cosine Distance): 3
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is known as the entertainment capital of the world, with its iconic Walk of Fame and the famous Hollywood sign. It is a bustling neighborhood with a mix of historic landmarks, trendy restaurants, and luxurious homes. ', 'House_Description': 'This beautiful home in Hollywood offers the perfect blend of modern amenities and classic charm. With 300 square meters of living space, this home features 3 bedrooms and 2 bathrooms, making it the perfect space for a growing family. The spacious backyard is perfect for entertaining guests or simply enjoying a quiet evening at home. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 3, 'Price': 1500000}"
#
# Results for both Euclidean and Cosine distance searches are identical

# %% [markdown]
# In this case, the use of euclidean vs cosine distance does not matter. It is interesting to note that this vector store does really poorly on retrieving a numbers question. It says the Malibu house is the cheapest. That makes no sense since it is 1,800,000. The least expensive is 500,000.

# %% [markdown]
# ## Step 6: Personalizing Listing Descriptions
#
# - LLM Augmentation: For each retrieved listing, use the LLM to augment the description, tailoring it to resonate with the buyer’s specific preferences. This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
# - Maintaining Factual Integrity: Ensure that the augmentation process enhances the appeal of the listing without altering factual information.

# %% [markdown]
# ### Process will be:
#
# - Select a buyer and a preference.
# - The preferences are in personal_df.
# - Use Q1 to search Chroma and come up with the top result only.
# - Lets use Q1 as the preference for enhancing the listing.
# - The prompt will give the personality, the retrieved listing from Chroma, and the location (again).
# - The prompt will include instructions for being creative to enhance the listing.
# - Instructions need to be given in the prompt that the LLM must only only use what is in the prompt for context.

# %%
enhanced_listing_prompt = """
You are an accomplished and creative real estate marketing executive who works in {location}. Your buyer is 
{personality}. The buyer will be interested in the following listing. 
###
{listing}
###
Please create a new listing that encapsulate the information contained in this listing and takes into account 
the buyer's preferences as follows.
###
{preferences}
###
When creating the new listing take poetic license but remain factual. Please reference price, number of bedrooms, 
and size of the home in your poetic listing. Also, wordsmith their preferences.
into the listing. 
"""
print(enhanced_listing_prompt)
# Out:
# You are an accomplished and creative real estate marketing executive who works in {location}. Your buyer is
# {personality}. The buyer will be interested in the following listing.
# ###
# {listing}
# ###
# Please create a new listing that encapsulate the information contained in this listing and takes into account
# the buyer's preferences as follows.
# ###
# {preferences}
# ###
# When creating the new listing take poetic license but remain factual. Please reference price, number of bedrooms,
# and size of the home in your poetic listing. Also, wordsmith their preferences.
# into the listing.

# %%
json_spec = """
###
Return the output in JSON format as follows. Please adhere EXACTLY to this ouput.

{'Neighborhoold_Name': 'Neighborhoold_Name',
 'Neighborhood_Description': 'Neighborhood_Description wiht Preferences',
 'House_Description': 'House_Description with Preferences',
 'Square_Meters': Square_Meters,
 'Bathrooms': Bathrooms,
 'Bedrooms': Bedrooms,
 'Price': Price}
###
"""
print(json_spec)
# Out:
# ###
# Return the output in JSON format as follows. Please adhere EXACTLY to this ouput.
#
# {'Neighborhoold_Name': 'Neighborhoold_Name',
#  'Neighborhood_Description': 'Neighborhood_Description wiht Preferences',
#  'House_Description': 'House_Description with Preferences',
#  'Square_Meters': Square_Meters,
#  'Bathrooms': Bathrooms,
#  'Bedrooms': Bedrooms,
#  'Price': Price}
# ###

# %%
data_list = []
for idx, row in enumerate(personal_df.itertuples()):
    
    # Define personality of buyer
    personality = personalities[idx]
    print(personality)
    
    # Search Chroma
    results = chromadb.similarity_search(row.Q2)[0]
    
    # Create the preferences for this buyer
    preferences = concat_row(row)
    
    formatted_prompt = enhanced_listing_prompt.format(
        personality = personality,
        listing = results,
        preferences = preferences,
        location = location)
    
    # Create the formatted prompt
    formatted_prompt = formatted_prompt + json_spec
    
    # Get the response from the LLM
    try:
        response = answers_model.predict(formatted_prompt)
    except Exception as e:
        print(f"Error occurred: {str(e)}")
        print('Non fatal error. We just get one fewer personalized listing.')
    
    # Clean the output
    cleaned_response = cleanup(response)
    
    # Parse the response to structured JSON
    try:
        structured_response = json.loads(cleaned_response)
        data_list.append(structured_response)
    except Exception as e:
        print(f"Error occurred: {str(e)}")
        print('Non fatal error. We just get one fewer personalized listing.')
    
len(data_list)
# Out:
# single, arrogant, rich, and female
# male, married, 2 kids, and middle class
# divorced middle aged woman, working 2 jobs, with dependent adult children
# young, nice, poor, male
# upper middle class married woman, husband works overseas, with no children
# 5

# %%
poetic_df = pd.DataFrame(data_list)
poetic_df
# Out:
#   Neighborhoold_Name                           Neighborhood_Description  \
# 0          Hollywood  Welcome to Hollywood, the perfect blend of gli...
# 1                NaN  Welcome to the upscale and picturesque neighbo...
# 2          Brentwood  Nestled in the heart of the charming and upsca...
# 3     West Hollywood  Nestled in the heart of the city, West Hollywo...
# 4          Brentwood  Experience luxury living in this stunning vill...
#
#                                    House_Description Square_Meters  Bathrooms  \
# 0  Indulge in the ultimate Hollywood dream with t...       >3, 000          2
# 1  Step into your stunning new villa in Brentwood...          2500          5
# 2  Welcome to your dream home in Brentwood - a sp...           500          5
# 3  This charming bungalow in West Hollywood offer...          1000          2
# 4  Welcome to your dream home in Brentwood. This ...           500          5
#
#    Bedrooms         Price Neighborhood_Name
# 0         3  $1, 500, 000               NaN
# 1         5  $2, 500, 000         Brentwood
# 2         5       2500000               NaN
# 3         2        750000               NaN
# 4         5       2500000               NaN

# %%
for idx, row in enumerate(poetic_df.itertuples()):
    
    # Get the Buyer
    print('Buyer is:', personalities[idx])
            
    # Get the Preferences for the Buyer
    print('Preferences are:')
    for col_num in range(len(personal_df)):
        print(col_num, personal_df.iloc[idx, col_num], '\n')
    
    # Get the original listing
    results = chromadb.similarity_search(row.Neighborhood_Description)[0]
    print('This is the original listing')
    print(results, '\n')
    
    print('This is the poetic license version')
    print(row.Neighborhood_Description)
    print(row.House_Description)
    print('###\n')
# Out:
# Buyer is: single, arrogant, rich, and female
# Preferences are:
# 0 I would like my house to be at least 3, 000 square feet.
#
# 1 The most important things for me in choosing this property are location, security, and luxury.
#
# 2 I would like amenities such as a pool, gym, and home theater.
#
# 3 Having easy access to public transportation and being close to major highways is important to me.
#
# 4 I will be living in the home alone.
#
# This is the original listing
# page_content="{'Neighborhoold_Name': 'Hollywood', 'Neighborhood_Description': 'Hollywood is the iconic neighborhood in Los Angeles, known for its glitz and glamour. It is home to the famous Hollywood Walk of Fame, where you can find the stars of your favorite celebrities. The neighborhood also offers a variety of entertainment options, including theaters, museums, and live music venues. With its central location, Hollywood is the perfect place to experience the best of LA. ', 'House_Description': 'This modern house in Hollywood is a true gem. With sleek and stylish design, this house is perfect for those who appreciate contemporary living. The open concept living area is perfect for entertaining, and the large windows offer stunning views of the city. The house also features a rooftop deck with a hot tub, perfect for relaxing and taking in the Hollywood skyline. ', 'Square_Meters': 300, 'Bathrooms': 3, 'Bedrooms': 4, 'Price': 1200000}"
#
# This is the poetic license version
# Welcome to Hollywood, the perfect blend of glitz and tranquility. This bustling urban neighborhood has all the amenities you desire, while still offering a peaceful retreat from the chaos of city life. With its iconic Walk of Fame and luxurious homes, Hollywood is the ideal location for someone like you - single, wealthy, and looking for the best.
# Indulge in the ultimate Hollywood dream with this stunning 3 bedroom, 2 bathroom home. Featuring over 3, 000 square feet of modern design and luxury, this property is perfect for entertaining guests or enjoying a quiet evening alone. The backyard oasis boasts a sparkling pool, fully-equipped gym, and state-of-the-art home theater, giving you the ultimate in-home entertainment experience.
# ###
#
# Buyer is: male, married, 2 kids, and middle class
# Preferences are:
# 0 I am looking for a house that is around 2, 000 to 2, 500 square feet.
#
# 1 The most important things for me in choosing this property are the location, size of the house, and safety of the neighborhood.
#
# 2 I would like amenities such as a backyard, a garage, and a modern kitchen.
#
# 3 Having access to public transportation and major highways is important to me for commuting to work.
#
# 4 My wife and I, both in our 30s, and our 2 young children will be living in the home.
#
# This is the original listing
# page_content="{'Neighborhoold_Name': 'Brentwood', 'Neighborhood_Description': 'Brentwood is an upscale and picturesque neighborhood known for its beautiful homes and tree-lined streets. It is located near the coast of Los Angeles and offers a peaceful and luxurious lifestyle. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This stunning villa in Brentwood offers 500 square meters of living space and features breathtaking views of the city and ocean. With 5 bedrooms and 5 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the chance to live in this exclusive and sought-after neighborhood. ', 'Square_Meters': 500, 'Bathrooms': 5, 'Bedrooms': 5, 'Price': 2500000}"
#
# This is the poetic license version
# Welcome to the upscale and picturesque neighborhood of Brentwood, where your dream home awaits. This suburban paradise offers a peaceful and luxurious lifestyle, perfect for you and your growing family. Enjoy tree-lined streets and easy access to nearby parks and recreational activities.
# Step into your stunning new villa in Brentwood, boasting 2500 square feet of modern elegance and breathtaking city and ocean views. This 5-bedroom, 5-bathroom home is perfect for your family`s needs, with a spacious backyard oasis featuring a pool, spa, and outdoor kitchen. Your new home is also equipped with a garage and a state-of-the-art kitchen, perfect for hosting friends and family.
# ###
#
# Buyer is: divorced middle aged woman, working 2 jobs, with dependent adult children
# Preferences are:
# 0 I would like my house to be at least 1500 square feet.
#
# 1 The 3 most important things for me in choosing this property are location, price, and safety.
#
# 2 I would like amenities such as a backyard, garage parking, and a laundry room.
#
# 3 Proximity to public transportation and easy access to major highways are important to me.
#
# 4 My dependent adult children, ages 20 and 23, will be living with me.
#
# This is the original listing
# page_content="{'Neighborhoold_Name': 'Brentwood', 'Neighborhood_Description': 'Brentwood is an upscale and picturesque neighborhood known for its beautiful homes and tree-lined streets. It is located near the coast of Los Angeles and offers a peaceful and luxurious lifestyle. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This stunning villa in Brentwood offers 500 square meters of living space and features breathtaking views of the city and ocean. With 5 bedrooms and 5 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the chance to live in this exclusive and sought-after neighborhood. ', 'Square_Meters': 500, 'Bathrooms': 5, 'Bedrooms': 5, 'Price': 2500000}"
#
# This is the poetic license version
# Nestled in the heart of the charming and upscale Brentwood neighborhood, this stunning villa offers a luxurious and peaceful lifestyle with all the amenities you could desire. With its tree-lined streets and proximity to shops and restaurants, it`s the perfect blend of urban convenience and suburban charm. And with 500 square meters of living space and 5 spacious bedrooms and bathrooms, there`s plenty of room for you and your adult children to spread out and relax. But the real crown jewel of this home is the private backyard oasis, complete with a sparkling pool, spa, and outdoor kitchen - perfect for entertaining or simply unwinding after a long day. Priced at $2, 500, 000, this home is a rare gem that combines location, price, and safety.
# Welcome to your dream home in Brentwood - a spacious and modern villa boasting 500 square meters of living space and breathtaking views of the city and ocean. With 5 luxurious bedrooms and 5 pristine bathrooms, this home is perfect for a large family or those who love to entertain. And with a backyard retreat that includes a pool, spa, and outdoor kitchen, you`ll never want to leave. But don`t just take our word for it - come see it for yourself and experience the luxurious lifestyle that only Brentwood can offer.
# ###
#
# Buyer is: young, nice, poor, male
# Preferences are:
# 0 I am looking for a house that is around 1000-1500 square feet.
#
# 1 The 3 most important things for me in choosing a property are: location, price, and safety.
#
# 2 I would like amenities such as a washer/dryer, updated kitchen, and a small backyard.
#
# 3 I would prefer a neighborhood with reliable public transportation options.
#
# 4 I will be living in the home with my partner, who is 25 years old and male.
#
# This is the original listing
# page_content="{'Neighborhoold_Name': 'West Hollywood', 'Neighborhood_Description': 'West Hollywood is a trendy and vibrant neighborhood known for its lively nightlife and diverse community. It is located in the heart of Los Angeles and offers a mix of modern and historic homes. Residents enjoy a variety of dining and entertainment options, as well as easy access to the rest of the city. ', 'House_Description': 'This modern penthouse in West Hollywood offers 200 square meters of living space and features sleek and contemporary design. With 2 bedrooms and 2 bathrooms, this house is perfect for young professionals or those looking for a modern urban lifestyle. The rooftop deck offers stunning views of the city and is perfect for outdoor entertaining. Don`t miss the opportunity to live in this vibrant and dynamic neighborhood. ', 'Square_Meters': 200, 'Bathrooms': 2, 'Bedrooms': 2, 'Price': 1000000}"
#
# This is the poetic license version
# Nestled in the heart of the city, West Hollywood offers an urban yet peaceful lifestyle. With a vibrant atmosphere and plenty of dining and entertainment options, this neighborhood is perfect for young professionals like you. Enjoy the convenience of reliable public transportation and the safety of a tight-knit community.
# This charming bungalow in West Hollywood offers 1000 square feet of modern living space. With 2 bedrooms and 2 bathrooms, this home is perfect for you and your partner. The updated kitchen and in-unit washer/dryer make for easy and convenient living. Step outside to your private backyard, perfect for your furry friend to play in. Don`t miss the opportunity to call this affordable and safe neighborhood home.
# ###
#
# Buyer is: upper middle class married woman, husband works overseas, with no children
# Preferences are:
# 0 Answer to Q0: I am looking for a house that is around 2, 000 to 3, 000 square feet.
#
# 1 Answer to Q1: The 3 most important things for me in choosing this property are location, safety, and convenience to amenities.
#
# 2 Answer to Q2: I would like a house with a backyard, a modern kitchen, and a home office.
#
# 3 Answer to Q3: The most important transportation options for me are proximity to public transportation and easy access to major highways.
#
# 4 Answer to Q4: My husband and I will be living in the home. We are both in our late 30s and have been married for 5 years.
# This is the original listing
# page_content="{'Neighborhoold_Name': 'Brentwood', 'Neighborhood_Description': 'Brentwood is an upscale and picturesque neighborhood known for its beautiful homes and tree-lined streets. It is located near the coast of Los Angeles and offers a peaceful and luxurious lifestyle. Residents enjoy a variety of outdoor activities, as well as top-rated schools and a strong sense of community. ', 'House_Description': 'This stunning villa in Brentwood offers 500 square meters of living space and features breathtaking views of the city and ocean. With 5 bedrooms and 5 bathrooms, this house is perfect for a large family or those who love to entertain. The backyard is a private oasis with a pool, spa, and outdoor kitchen. Don`t miss the chance to live in this exclusive and sought-after neighborhood. ', 'Square_Meters': 500, 'Bathrooms': 5, 'Bedrooms': 5, 'Price': 2500000}"
#
# This is the poetic license version
# Experience luxury living in this stunning villa located in the upscale and picturesque neighborhood of Brentwood. This modern home offers a spacious backyard with a pool, spa, and outdoor kitchen, perfect for entertaining or relaxing after a long day. Safety is a top priority in this community, with easy access to major highways and public transportation for added convenience. The neighborhood also boasts a mix of residential and commercial areas, providing the perfect balance of urban living. Don`t miss out on the opportunity to live in this highly sought-after neighborhood.
# Welcome to your dream home in Brentwood. This exquisite villa offers 5 bedrooms and 5 bathrooms, providing plenty of space for a growing family or for hosting guests. Enjoy breathtaking views of the city and ocean from the comfort of your own private oasis. The modern kitchen and home office add a touch of functionality and convenience to this already perfect home. With a garage and laundry room included, this house has everything you need and more. Priced at $2, 500, 000, this is a once in a lifetime opportunity you won`t want to miss.
# ###

# %% [markdown]
# It is factual, reflects the buyers preferences, and creative as requested!!
